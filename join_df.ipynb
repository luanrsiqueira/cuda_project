# %%
import pandas as pd

# %%
data = pd.read_csv('./csv_files/csv/All-App-GPU.csv')
data.head()
# Out:
# /home/luan/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (27,35,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  compute_version  gpu_id gpu_name  l1_cache_used  \
# 0           1              3.0     1.0  GTX-680            0.0
# 1           2              3.0     1.0  GTX-680            0.0
# 2           3              3.0     1.0  GTX-680            0.0
# 3           4              3.0     1.0  GTX-680            0.0
# 4           5              3.0     1.0  GTX-680            0.0
#
#    max_clock_rate  num_of_cores   L2    bus  memory_clock  ...  block_z  \
# 0          1058.0        1536.0  0.5  256.0        3004.0  ...      1.0
# 1          1058.0        1536.0  0.5  256.0        3004.0  ...      1.0
# 2          1058.0        1536.0  0.5  256.0        3004.0  ...      1.0
# ...

# %%
df = pd.read_csv('./cuda_to_csv/output.csv', sep=',', names=['null','AppName','block_x','compute_version','registers','smem','cmem','number_of_lines_function','occupancy'])
df.head()
# Out:
#    null               AppName  block_x  compute_version  registers  smem  \
# 0     0  matMul_gpu_sharedmem        8              3.0         32   512
# 1     1  matMul_gpu_sharedmem       16              3.0         25  2048
# 2     2  matMul_gpu_sharedmem       32              3.0         25  8192
# 3     3  matMul_gpu_sharedmem        8              3.5         32   512
# 4     4  matMul_gpu_sharedmem       16              3.5         25  2048
#
#    cmem  number_of_lines_function  occupancy
# 0   348                        15      100.0
# 1   348                        15      100.0
# 2   348                        15       38.0
# 3   348                        15      100.0
# 4   348                        15      100.0

# %%
new_dataset = pd.merge(df, data, how = 'inner', on = ['AppName','compute_version', 'block_x'])
#new_dataset.to_csv('new_dataset.csv')
new_dataset
# Out:
#       null               AppName  block_x  compute_version  registers_x  \
# 0        0  matMul_gpu_sharedmem        8              3.0           32
# 1        0  matMul_gpu_sharedmem        8              3.0           32
# 2        0  matMul_gpu_sharedmem        8              3.0           32
# 3        0  matMul_gpu_sharedmem        8              3.0           32
# 4        0  matMul_gpu_sharedmem        8              3.0           32
# ...    ...                   ...      ...              ...          ...
# 5219     8  matrix_sum_coalesced       32              5.2            8
# 5220     8  matrix_sum_coalesced       32              5.2            8
# 5221     8  matrix_sum_coalesced       32              5.2            8
# 5222     8  matrix_sum_coalesced       32              5.2            8
# 5223     8  matrix_sum_coalesced       32              5.2            8
#
#       smem_x  cmem_x  number_of_lines_function  occupancy_x  Unnamed: 0  ...  \
# ...

# %%
new_dataset.drop(columns=[])
new_dataset
# Out:
#       null               AppName  block_x  compute_version  registers_x  \
# 0        0  matMul_gpu_sharedmem        8              3.0           32
# 1        0  matMul_gpu_sharedmem        8              3.0           32
# 2        0  matMul_gpu_sharedmem        8              3.0           32
# 3        0  matMul_gpu_sharedmem        8              3.0           32
# 4        0  matMul_gpu_sharedmem        8              3.0           32
# ...    ...                   ...      ...              ...          ...
# 5219     8  matrix_sum_coalesced       32              5.2            8
# 5220     8  matrix_sum_coalesced       32              5.2            8
# 5221     8  matrix_sum_coalesced       32              5.2            8
# 5222     8  matrix_sum_coalesced       32              5.2            8
# 5223     8  matrix_sum_coalesced       32              5.2            8
#
#       smem_x  cmem_x  number_of_lines_function  occupancy_x  Unnamed: 0  ...  \
# ...
