# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./All-App-GPU.csv')
data = data[['AppName','compute_version','gpu_id','gpu_name','max_clock_rate','num_of_cores','L2','bus','memory_clock','bandwith','GM','num_sm','num_cores_sm','theoretical_flops','AppId','duration','grid_x','grid_y','block_x','block_y']]
data
# Out:
# C:\Users\Luan Siqueira\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                      AppName  compute_version  gpu_id gpu_name  \
# 0     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 1     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 2     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 3     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 4     matMul_gpu_uncoalesced              3.0       1  GTX-680
# ...                      ...              ...     ...      ...
# 8454               subSeqMax              5.2       8  GTX-980
# 8455               subSeqMax              5.2       8  GTX-980
# 8456               subSeqMax              5.2       8  GTX-980
# 8457               subSeqMax              5.2       8  GTX-980
# ...

# %%
data['bandwith'].unique()
# Out:
# array([1.92256e+05, 2.88384e+05, 2.08000e+02, 3.36480e+02, 2.24320e+02])

# %%
data = pd.read_csv('./All-App-GPU.csv')
data = data[['AppName','compute_version','gpu_id','gpu_name','max_clock_rate','num_of_cores','L2','bus','memory_clock','bandwith','GM','num_sm','num_cores_sm','theoretical_flops','AppId','duration','grid_x','grid_y','block_x','block_y']]
'''
a_trocar = {
    '"' : '',
    ',' : '.'
}

data.duration = data.duration.map(a_trocar)
data.head()
'''
#dados = data['duration'].to_string()
#dados.to_d('duration.csv')

#tt=re.findall(r'\"(.+?)\"', str(data['duration']))
#data['duration'] = "".join(tt)
#data['duration'] = data['duration'].replace(',','.')

#data['duration'] = data['duration'].astype(float).round(4)
data.to_csv('all-app-gpu-24-09.csv')
#data = data.drop(columns= ["Unnamed: 0","input_size"], axis = 1)
#data
# Out:
# C:\Users\Luan Siqueira\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (27,35,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dados = pd.read_csv('./all-app-gpu-24-09.csv')
dados = dados.drop(columns= ["Unnamed: 0"], axis = 1)
dados
# Out:
#                      AppName  compute_version  gpu_id gpu_name  \
# 0     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 1     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 2     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 3     matMul_gpu_uncoalesced              3.0       1  GTX-680
# 4     matMul_gpu_uncoalesced              3.0       1  GTX-680
# ...                      ...              ...     ...      ...
# 8454               subSeqMax              5.2       8  GTX-980
# 8455               subSeqMax              5.2       8  GTX-980
# 8456               subSeqMax              5.2       8  GTX-980
# 8457               subSeqMax              5.2       8  GTX-980
# 8458               subSeqMax              5.2       8  GTX-980
#
#       max_clock_rate  num_of_cores   L2  bus  memory_clock bandwith  GM  \
# 0               1058          1536  0.5  256          3004   192256   2
# ...

# %%
df = pd.read_csv('./cuda_to_csv/new_test.csv', sep=',', names=['null','AppName','block_x','compute_version','registers','smem','cmem', 'number_of_lines_kernel','occupancy'])
df = df.drop(columns= ["null"], axis = 1)
#df.to_csv('Teste-25-09.csv')
df
# Out:
#                  AppName  block_x  compute_version  registers  smem  cmem  \
# 0   matMul_gpu_sharedmem        8              3.0         32   512   348
# 1   matMul_gpu_sharedmem       16              3.0         25  2048   348
# 2   matMul_gpu_sharedmem       32              3.0         25  8192   348
# 3   matMul_gpu_sharedmem        8              3.5         32   512   348
# 4   matMul_gpu_sharedmem       16              3.5         25  2048   348
# ..                   ...      ...              ...        ...   ...   ...
# 70               dotProd      256              3.5         13  1024   348
# 71               dotProd     1024              3.5         13  4096   348
# 72               dotProd       64              5.2         13   256   348
# 73               dotProd      256              5.2         13  1024   348
# 74               dotProd     1024              5.2         13  4096   348
#
#     number_of_lines_kernel  occupancy
# 0                       15         50
# ...

# %%
new_dataset = pd.merge(data, df, how = 'inner', on = ['AppName','compute_version','block_x'])
new_dataset.to_csv('Teste-30-09.csv')
#new_dataset[(new_dataset['AppName'] == 'dotProd') & (new_dataset['compute_version'] == 5.2) & (new_dataset['block_x'] == 1024)]
