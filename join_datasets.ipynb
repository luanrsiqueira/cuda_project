# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./All-App-GPU.csv')
#df = pd.read_csv('./cuda_to_csv/output.csv', sep=',', names=['null','AppName','tw','compute_version','registers','smem','cmem','number_of_lines_function','occupancy','AppId'])
df = pd.read_csv('./cuda_to_csv/new_test_tw16.csv', sep=',', names=['null','AppName','block_x','compute_version','registers','smem','cmem', 'number_of_lines_kernel','occupancy'])

# %%
new_dataset = pd.merge(df, data, how = 'inner', on = ['AppName','compute_version','block_x'])
new_dataset.to_csv('Teste-11-08_tw16.csv')
new_dataset
# Out:
#       null               AppName  block_x  compute_version  registers  smem  \
# 0        0  matMul_gpu_sharedmem       16              3.0         25  2048
# 1        0  matMul_gpu_sharedmem       16              3.0         25  2048
# 2        0  matMul_gpu_sharedmem       16              3.0         25  2048
# 3        0  matMul_gpu_sharedmem       16              3.0         25  2048
# 4        0  matMul_gpu_sharedmem       16              3.0         25  2048
# ...    ...                   ...      ...              ...        ...   ...
# 3097     2               dotProd      256              5.2         13  1024
# 3098     2               dotProd      256              5.2         13  1024
# 3099     2               dotProd      256              5.2         13  1024
# 3100     2               dotProd      256              5.2         13  1024
# 3101     2               dotProd      256              5.2         13  1024
#
# ...
