# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('./datasets/model.csv', sep=',')
df1
# Out:
#    Application              Model   MAPE
# 0         MMGU      Random Forest   5.69
# 1         MMGC      Random Forest   0.94
# 2         MMSU      Random Forest   0.52
# 3         MMSC      Random Forest  22.65
# 4          MAC      Random Forest   0.08
# 5          MAU      Random Forest   0.01
# 6         dotP      Random Forest   0.02
# 7         vAdd      Random Forest   0.01
# 8          MSA      Random Forest   0.42
# 9         MMGU      Decision Tree   3.76
# 10        MMGC      Decision Tree   0.58
# 11        MMSU      Decision Tree   0.66
# 12        MMSC      Decision Tree   0.78
# 13         MAC      Decision Tree   0.01
# 14         MAU      Decision Tree   0.01
# 15        dotP      Decision Tree   0.02
# 16        vAdd      Decision Tree   0.01
# 17         MSA      Decision Tree   0.05
# 18        MMGU  Linear Regression  36.27
# 19        MMGC  Linear Regression  24.75
# 20        MMSU  Linear Regression  25.66
# 21        MMSC  Linear Regression  17.21
# ...

# %%
small_data = df1[['Application', 'Model','MAPE',]]
small_data = small_data.melt(id_vars=['Scenario Name', 'Concurrent Users'])

g = sns.barplot(x="Concurrent Users", y="value", hue='new_var', data=small_data)
sns.set(rc={'figure.figsize':(11,8)})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Luan_Siqueira\tcc\cuda_project\cuda_project\plot_graphic.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Luan_Siqueira/tcc/cuda_project/cuda_project/plot_graphic.ipynb#ch0000002?line=0'>1</a> small_data = df1[['Application', 'Model','MAPE',]]
# ----> <a href='vscode-notebook-cell:/c%3A/Luan_Siqueira/tcc/cuda_project/cuda_project/plot_graphic.ipynb#ch0000002?line=1'>2</a> small_data = small_data.melt(id_vars=['Scenario Name', 'Concurrent Users'])
#       <a href='vscode-notebook-cell:/c%3A/Luan_Siqueira/tcc/cuda_project/cuda_project/plot_graphic.ipynb#ch0000002?line=3'>4</a> g = sns.barplot(x="Concurrent Users", y="value", hue='new_var', data=small_data)
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
df = pd.DataFrame({ 
    'Name': ['Application', 'Model', 'MAPE'], 
    'Age': [45, 38, 90], 
    'Age': [51, 40, 180], 
    'Height(in cm)': [150, 180, 160] 
}) 
df.plot(x="Name", y=["Age", "Height(in cm)"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Name'>
