# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('./model.csv', sep=',')
df1
# Out:
#     application          model  prediction
# 0           1.0  Random Forest       12.13
# 1           2.0  Random Forest       11.70
# 2           3.0  Random Forest        7.55
# 3           4.0  Random Forest       17.29
# 4           5.0  Random Forest        1.62
# 5           6.0  Random Forest        1.44
# 6           7.0  Random Forest        2.59
# 7           8.0  Random Forest        1.37
# 8           9.0  Random Forest        4.06
# 9           1.0  Decision Tree        3.64
# 10          2.0  Decision Tree        1.01
# 11          3.0  Decision Tree        0.80
# 12          4.0  Decision Tree       11.76
# 13          5.0  Decision Tree        0.89
# 14          6.0  Decision Tree        0.10
# 15          7.0  Decision Tree        0.10
# 16          8.0  Decision Tree        0.81
# 17          9.0  Decision Tree        0.16

# %%
small_data = df1[['Application', 'Model','MAPE',]]
small_data = small_data.melt(id_vars=['Scenario Name', 'Concurrent Users'])

g = sns.barplot(x="Concurrent Users", y="value", hue='new_var', data=small_data)
sns.set(rc={'figure.figsize':(11,8)})

# %%
sns.factorplot(x='application', y='prediction', hue='model', data=df1, kind='bar')
# Out:
# C:\Users\Luan Siqueira\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
